# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('311_Service_Requests_from_2010_to_Present_SI.csv')
# Out:
# /Users/hyejinkim/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.drop(['Agency', 'Due Date', 'Facility Type', 'Cross Street 1', 'Cross Street 2', 
           'Intersection Street 1', 'Intersection Street 2', 'Community Board', 'BBL', 
           'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 
           'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction',
           'Road Ramp', 'Bridge Highway Segment'], axis = 1, inplace=True)

# %%
data = data[data['Borough'] != 'Unspecified']

# %%
data['Year'] = pd.DatetimeIndex(data['Created Date']).year
data['Month'] = pd.DatetimeIndex(data['Created Date']).month
data['Year_Month'] = pd.to_datetime(data[['Year', 'Month']].assign(DAY=1))

# %%
data.loc[data['Complaint Type'] == 'Dirty Condition', 'Complaint Type'] = 'Dirty Conditions'

# %%
# Descriptors to drop within dirty conditions category

dirty_conditions_drop = ['Broken Glass', 'Debris from Car Accident', 'Dirt or Gravel', 'Dog Waste', 
                         'E15 Illegal Postering', 'E4 18" Law', 'E8 Canine Violation', 'Poster or Sign', 'Syringes']

# %%
# Dropped the above
data = data.drop(data[data.Descriptor.isin(dirty_conditions_drop)].index)

#749006 rows left

# %%
food_establishment_keep = ['No Permit or License', 'Permit/License/Certificate', 'Rodents/Insects/Garbage']

# %%
data_food = data[data['Descriptor'].isin(food_establishment_keep)]

# %%
#remove all Food Establishment

data = data[data['Complaint Type'] != 'Food Establishment']

# %%
data = pd.concat([data, data_food], axis=0)

# %%
#remove the following illegal parking types
illegal_parking_drop = ['Overnight Commercial Storage', 'Detached Trailer', 'Unauthorized Bus Layover']

# %%
# Dropped the above
data = data.drop(data[data.Descriptor.isin(illegal_parking_drop)].index)

# %%
data
# Out:
#         Unique Key            Created Date             Closed Date  \
# 0         20065513  03/19/2011 10:59:00 AM  03/22/2011 12:00:00 PM
# 1         20070150  03/20/2011 03:31:00 PM  03/25/2011 12:00:00 PM
# 2         45830228  03/14/2020 09:55:28 PM  03/14/2020 11:30:07 PM
# 3         20069524  03/20/2011 03:43:00 PM  03/22/2011 12:00:00 PM
# 5         20069527  03/20/2011 08:06:00 PM  03/22/2011 12:00:00 PM
# ...            ...                     ...                     ...
# 163813    42091285  03/30/2019 12:23:48 PM  05/30/2019 06:11:12 AM
# 163824    42092372  03/30/2019 06:01:38 PM  05/30/2019 06:11:14 AM
# 163858    42096438  03/30/2019 10:33:25 AM  05/30/2019 06:11:12 AM
# 164148    42135473  04/04/2019 07:26:59 AM  06/04/2019 06:12:33 AM
# 164321    42159168  04/07/2019 04:53:08 PM  06/07/2019 06:14:57 AM
#
#                                     Agency Name      Complaint Type  \
# 0                             A - Staten Island    Dirty Conditions
# 1                P - Brooklyn and Staten Island    Dirty Conditions
# 2               New York City Police Department     Illegal Parking
# 3                             A - Staten Island    Dirty Conditions
# 5                             A - Staten Island    Dirty Conditions
# ...                                         ...                 ...
# 163813  Department of Health and Mental Hygiene  Food Establishment
# 163824  Department of Health and Mental Hygiene  Food Establishment
# 163858  Department of Health and Mental Hygiene  Food Establishment
# 164148  Department of Health and Mental Hygiene  Food Establishment
# 164321  Department of Health and Mental Hygiene  Food Establishment
#
#                               Descriptor               Location Type  \
# 0                      E3 Dirty Sidewalk                    Sidewalk
# 1       E12 Illegal Dumping Surveillance                    Sidewalk
# 2          Posted Parking Sign Violation             Street/Sidewalk
# 3                      E3 Dirty Sidewalk                    Sidewalk
# 5                E3A Dirty Area/Alleyway                         Lot
# ...                                  ...                         ...
# 163813           Rodents/Insects/Garbage  Restaurant/Bar/Deli/Bakery
# 163824           Rodents/Insects/Garbage  Restaurant/Bar/Deli/Bakery
# 163858        Permit/License/Certificate                   Residence
# 164148           Rodents/Insects/Garbage       Other (Explain Below)
# 164321           Rodents/Insects/Garbage  Restaurant/Bar/Deli/Bakery
#
#         Incident Zip      Incident Address      Street Name  ...  \
# 0            10306.0         RICHMOND ROAD    RICHMOND ROAD  ...
# 1            10306.0     331 HUNTER AVENUE    HUNTER AVENUE  ...
# 2            10304.0      449 WESER AVENUE     WESER AVENUE  ...
# 3            10314.0          YUKON AVENUE     YUKON AVENUE  ...
# 5            10304.0     1 CHESTNUT STREET  CHESTNUT STREET  ...
# ...              ...                   ...              ...  ...
# 163813       10306.0    2481 RICHMOND ROAD    RICHMOND ROAD  ...
# 163824       10305.0  1661 HYLAN BOULEVARD  HYLAN BOULEVARD  ...
# 163858       10304.0        25 MARY STREET      MARY STREET  ...
# 164148       10305.0  1565 HYLAN BOULEVARD  HYLAN BOULEVARD  ...
# 164321       10312.0   854 ARTHUR KIL ROAD  ARTHUR KIL ROAD  ...
#
#        Resolution Action Updated Date        Borough  \
# 0              03/22/2011 12:00:00 PM  STATEN ISLAND
# 1              03/25/2011 12:00:00 PM  STATEN ISLAND
# 2              03/14/2020 11:30:13 PM  STATEN ISLAND
# 3              03/22/2011 12:00:00 PM  STATEN ISLAND
# 5              03/22/2011 12:00:00 PM  STATEN ISLAND
# ...                               ...            ...
# 163813         05/30/2019 06:11:12 AM  STATEN ISLAND
# 163824         05/30/2019 06:11:14 AM  STATEN ISLAND
# 163858         05/30/2019 06:11:12 AM  STATEN ISLAND
# 164148         06/04/2019 06:12:33 AM  STATEN ISLAND
# 164321         06/07/2019 06:14:57 AM  STATEN ISLAND
#
#        X Coordinate (State Plane) Y Coordinate (State Plane)   Latitude  \
# 0                        946688.0                   148110.0  40.573124
# 1                        956988.0                   150074.0  40.578553
# 2                        960259.0                   159755.0  40.605134
# 3                        938413.0                   148715.0  40.574746
# 5                        960477.0                   165303.0  40.620363
# ...                           ...                        ...        ...
# 163813                   950657.0                   148930.0  40.575391
# 163824                   959065.0                   153570.0  40.588155
# 163858                   960333.0                   162406.0  40.612411
# 164148                   959639.0                   154419.0  40.590486
# 164321                   937292.0                   143676.0  40.560909
#
#         Longitude                                  Location  Year  Month  \
# 0      -74.135208     (40.5731241316492, -74.1352082901508)  2011      3
# 1      -74.098140   (40.57855257723265, -74.09814033602167)  2011      3
# 2      -74.086399   (40.60513442383097, -74.08639946184654)  2020      3
# 3      -74.164999   (40.57474581506658, -74.16499904342676)  2011      3
# 5      -74.085634    (40.6203631204647, -74.08563390517311)  2011      3
# ...           ...                                       ...   ...    ...
# 163813 -74.120926    (40.57539079572836, -74.1209255595297)  2019      3
# 163824 -74.090676   (40.58815454275578, -74.09067638739472)  2019      3
# 163858 -74.086142    (40.61241107184313, -74.0861423522933)  2019      3
# 164148 -74.088613  (40.590486489244036, -74.08861284426779)  2019      4
# 164321 -74.168999   (40.56090889885669, -74.16899929251021)  2019      4
#
#         Year_Month
# 0       2011-03-01
# 1       2011-03-01
# 2       2020-03-01
# 3       2011-03-01
# 5       2011-03-01
# ...            ...
# 163813  2019-03-01
# 163824  2019-03-01
# 163858  2019-03-01
# 164148  2019-04-01
# 164321  2019-04-01
#
# [159273 rows x 25 columns]

# %%
df_2010_2021.to_csv('311_Service_Requests_from_2010_to_Present_SI_2.csv')

# %%
# Drop 2022 data for yearly graph
df_2010_2021 = data.drop(data[data.Year_Month == '2022-02-01'].index)

# %%
df_2010_2021 = df_2010_2021.groupby('Year_Month')[['Unique Key']].count()

# %%
df_2010_2021.rename(columns={'Unique Key': 'Total Complaints'}, inplace=True)

# %%
df_2010_2021.reset_index(inplace=True)

# %%
l = [x[:7] for x in df_2010_2021['Year_Month'].astype(str)]

# %%
import re
xlabelsnew = []
for i in l:
    if re.search('....-01', i) != None:
        xlabelsnew.append(i)
    else:
        xlabelsnew.append(' ')

# %%
x = df_2010_2021['Year_Month']
y = df_2010_2021['Total Complaints']
labels = xlabelsnew

plt.plot(x, y)

# You can specify a rotation for the tick labels in degrees or with keywords.
plt.rcParams["figure.figsize"] = (15, 5)

plt.xticks(x, labels, rotation='vertical')

# Pad margins so that markers don't get clipped by the axes
plt.margins(0.01)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.tick_params(axis='x', labelrotation = 45)
plt.show()

# %%
si = [x for x in df_2010_2021['Total Complaints']]

# %%
df = pd.DataFrame({
   'Staten Island': si
   }, index=df_2010_2021['Year_Month'])
lines = df.plot.line()
plt.xlabel("Complaints 2010-2021")
plt.ylabel("Volume of Complaints")
plt.tick_params(axis='x', labelrotation = 0)

# %%
df_2010_2021
# Out:
#     Year_Month  Total Complaints
# 0   2010-01-01               319
# 1   2010-02-01               272
# 2   2010-03-01               388
# 3   2010-04-01               427
# 4   2010-05-01               430
# 5   2010-06-01               630
# 6   2010-07-01               603
# 7   2010-08-01               632
# 8   2010-09-01               666
# 9   2010-10-01               608
# 10  2010-11-01               504
# 11  2010-12-01               531
# 12  2011-01-01               765
# 13  2011-02-01               679
# 14  2011-03-01               670
# 15  2011-04-01               544
# 16  2011-05-01               617
# 17  2011-06-01               698
# 18  2011-07-01               652
# 19  2011-08-01               514
# 20  2011-09-01               670
# 21  2011-10-01               561
# 22  2011-11-01               499
# 23  2011-12-01               477
# 24  2012-01-01               501
# 25  2012-02-01               521
# 26  2012-03-01               591
# 27  2012-04-01               564
# 28  2012-05-01               611
# 29  2012-06-01               628
# 30  2012-07-01               625
# 31  2012-08-01               585
# 32  2012-09-01               635
# 33  2012-10-01               507
# 34  2012-11-01               373
# 35  2012-12-01               443
